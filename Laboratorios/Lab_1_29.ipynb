# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
# código

##################################################################################################################
#          Función
##################################################################################################################

def cargar_archivos(archivo):  
    with open ("./Archivos/"+ archivo + ".txt", "r") as archivo:
        lineas = archivo.read()
        lineas = lineas.splitlines()
    return(lineas)   

##################################################################################################################
#          Iterar y cargar archivos en un diccionarios de todas las bases txt usando la función
##################################################################################################################

archivos = ["edad", "escolaridad", "estado_civil", "estrato", "promedio", "genero", "region" ]
conteo = 0 
diccionarios_datos = {}
while conteo <= len(archivos)-1:
    diccionarios_datos[archivos[conteo]] = cargar_archivos(archivos[conteo])
    conteo += 1
print(diccionarios_datos)
# Out:
# {'edad': ['36', '66', '24', '55', '26', '69', '79', '54', '51', '80', '30', '64', '40', '53', '47', '24', '76', '65', '38', '37', '71', '51', '51', '33', '24', '71', '78', '75', '38', '49', '49', '53', '62', '26', '67', '68', '70', '57', '47', '30', '44', '22', '30', '64', '21', '54', '35', '52', '27', '20', '59', '40', '23', '58', '71', '77', '70', '31', '19', '31', '75', '63', '79', '67', '46', '79', '30', '19', '64', '52', '79', '35', '74', '18', '22', '58', '77', '22', '73', '59', '18', '46', '35', '38', '80', '65', '41', '46', '36', '46', '56', '37', '67', '20', '46', '62', '70', '31', '20', '64', '78', '66', '45', '43', '70', '43', '24', '58', '62', '60', '80', '73', '73', '57', '42', '51', '52', '58', '39', '43', '66', '32', '49', '44', '57', '39', '21', '27', '31', '28', '44', '80', '71', '33', '22', '78', '60', '70', '62', '45', '78', '78', '42', '21', '44', '38', '19', '31', '58', '69', '34', '69', '80', '20', '59', '29', '33', '29', '44', '55', '47', '26', '47', '20', '43'
# ...

# %% [markdown]
# **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código

# importación de paquetes necesarios
import matplotlib.pyplot as plt

# función que calcula la mediana de una lista de datos numéricos
def mediana(lista):
    datos_a_organizar = lista[:]
    datos_a_organizados = sorted(datos_a_organizar)
    if len(datos_a_organizados)%2 != 0:
        mediana = float(datos_a_organizados[int(len(datos_a_organizados)/2)])
        return(mediana)
    else:
        mediana = (float(datos_a_organizados[int(len(datos_a_organizados)/2)-1]) + float(datos_a_organizados[(int(len(datos_a_organizados)/2))])) /2
        return(mediana)
    
mediana(diccionarios_datos["promedio"])

# función que calcula la desviación de una lista de datos numéricos

def desv (l):
    lista = l
    n = len(lista)
    distancia = 0
    promedio= sum(float(i) for i in lista)/n    
    for i in lista:
        distancia += (float(i) - promedio)**2
        dstd = (distancia/n)**(1/2)
    return(dstd)

desv(diccionarios_datos['edad'])


#Desviacion y mediana para los grupos de los diferentes factores  

diccionario_de_diccionarios = {}
for k in diccionarios_datos:
    variables = []
    for i in range(len(diccionarios_datos['promedio'])):
        variables.append((diccionarios_datos[k][i], float(diccionarios_datos['promedio'][i])))

    diccionario = {}#poblacion, mediana, desviación, conteo
    for i in set(diccionarios_datos[k]):  
        valores = []
        med = 0
        std = 0
        conteo = 0
        for j in variables:
            if i == j[0]:
                valores.append(j[1])
                med = mediana(valores)
                std = desv(valores) 
                conteo = conteo + 1
            diccionario[i] = (round(med,1), round(std,1), conteo)

    diccionario_de_diccionarios[k]= diccionario


diccionario_de_diccionarios_disp = {}    
for k in diccionarios_datos:
    variables = []
    for i in range(len(diccionarios_datos['promedio'])):
        variables.append((diccionarios_datos[k][i], float(diccionarios_datos['promedio'][i])))

    diccionario = {}#poblacion, promedios
    for i in set(diccionarios_datos[k]):  
        valores = []
        med = 0
        std = 0
        
        for j in variables:
            if i == j[0]:
                valores.append(j[1])
        diccionario[i] = valores
    diccionario_de_diccionarios_disp[k]= diccionario
    
    
    
    
del diccionario_de_diccionarios["promedio"]
#Desviacion y mediana para los grupos de los diferentes factores 
print(diccionario_de_diccionarios)

del diccionario_de_diccionarios_disp["promedio"]
#valores por cada grupo

    
# función que visualiza las características de una población dada

def multiples_boxplot (dicc):
    for i in dicc:
        for j in dicc[i]:
            plt.boxplot(dicc[i][j])
            plt.title(i)
            plt.xlabel(j)
            plt.ylabel("promedio")
            plt.show()

multiples_boxplot(diccionario_de_diccionarios_disp)
# Out:
# {'edad': {'68': (2.7, 0.9, 6), '46': (3.0, 1.1, 9), '57': (2.7, 1.0, 12), '51': (3.0, 1.1, 5), '53': (3.0, 0.9, 10), '67': (2.6, 1.2, 9), '40': (3.3, 0.6, 5), '37': (2.5, 1.2, 4), '56': (2.9, 0.9, 4), '79': (3.2, 0.9, 9), '80': (3.1, 0.7, 11), '75': (3.0, 1.0, 10), '31': (2.1, 0.8, 7), '50': (3.0, 1.3, 10), '20': (2.5, 1.0, 11), '64': (3.0, 1.1, 8), '49': (3.4, 0.9, 7), '33': (2.5, 0.8, 6), '28': (3.1, 1.1, 6), '76': (3.4, 1.3, 7), '52': (2.9, 0.8, 8), '34': (2.4, 1.2, 7), '38': (2.9, 1.1, 9), '18': (2.3, 1.1, 7), '45': (2.8, 0.7, 8), '66': (2.9, 0.8, 12), '30': (2.5, 1.0, 9), '47': (3.3, 1.1, 7), '65': (2.6, 0.8, 7), '71': (2.6, 0.9, 9), '77': (2.6, 0.5, 7), '29': (2.2, 0.9, 10), '62': (3.5, 0.6, 6), '39': (2.4, 1.0, 8), '59': (3.3, 1.5, 7), '23': (2.2, 1.1, 7), '61': (2.5, 0.8, 4), '19': (1.4, 1.2, 8), '73': (3.2, 0.9, 5), '69': (3.6, 1.3, 10), '70': (3.3, 1.2, 11), '44': (3.1, 0.8, 9), '58': (3.1, 0.7, 11), '35': (2.1, 1.0, 9), '72': (0.7, 0.0, 1), '27': (2.5, 1.1, 10), '63': (3.0
# ...

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

pregunta_negocio = 'Qué cantidad de becas debo asignar de acuerdo al presupuesto de becas?'

pregunta_analytics = '¿Cómo debería ser desarrollado el metodo análitico que permita la mejor asignación de becas de acuerdo a los criterios económicos y académicos?  '

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
# código
import numpy as np

indice = 0
becas =[]
for i in range(len(diccionarios_datos['promedio'])):
    indice = indice +1
    becas.append((diccionarios_datos["estrato"][i], float(diccionarios_datos['promedio'][i]), indice))


diccionario_estratos_promedio_ordenados = {}
diccionario_estratos_promedio = {}#estrato, promedio, id
for i in sorted(set([i[0] for i in becas])):  
    valores = []
    for j in becas:
        if i == j[0]:
            valores.append(j[1:3])
            c= valores 
        
        diccionario_estratos_promedio_ordenados[i] =sorted(valores, reverse =True) ##validar datos
        diccionario_estratos_promedio[i] = valores

becas = []   
diccionario_becas = {}
becados_total = {} 
cont= 0 #contador becas dadas 
#Se daran 10 becas 0.02*500
nro_becas = int(len(diccionarios_datos["promedio"])*0.02)
#2% por sub poblacion 
proporcion = 0.02

#se repartiran esas 10 becas al 2% de cada sub poblacion segun promedio

while cont + 1 <= nro_becas:
    for j in diccionario_estratos_promedio:
        becas = []
        entraron = []
        final = []
        for i in  diccionario_estratos_promedio[j]:
            #crieterios para posibles becados
            if i[0] >= np.quantile([n[0] for n in diccionario_estratos_promedio[j]],0.75): #mejor quartil 3 
                
                becas.append((i[0], i[1], "beca"))
                becas = sorted(becas, reverse =True)
            diccionario_becas[j] = becas
        for  i in range(len(diccionario_becas[j])):
            #becas para 2% de cada sub poblacion 
            if i <= int((len(diccionario_estratos_promedio[j])*proporcion)):
                if cont == nro_becas:
                        break
                cont += 1
                final.append(diccionario_becas[j][i])
        diccionario_becas[j] = final 
        
        if diccionario_becas[j] != []:
            becados_total[j] = diccionario_becas[j] #base final 
        
        becados =[i[1] for i in final]

        for i in becados:
            for n in range(len(diccionario_estratos_promedio[j])):
                if diccionario_estratos_promedio[j][n][1] == i:
                    del diccionario_estratos_promedio[j][n]
                    break
conteo ={}
c= 0
for i in becados_total:
    c= 0
    for j in becados_total[i]: 
        c +=1
    conteo[i] = c

id_becados_por_estrato = {}
for i in becados_total:
    ids = []
    for j in becados_total[i]: 
        ids.append(j[1])
    id_becados_por_estrato[i] = ids
    
    
    
print("nro becados por estrato:", conteo)  
print("informacion becados(promedio, id, becado) :",becados_total)
print("id becados por estrato",id_becados_por_estrato)
# Out:
# nro becados por estrato: {'1': 3, '2': 4, '3': 3}
# informacion becados(promedio, id, becado) : {'1': [(5.0, 377, 'beca'), (4.9, 364, 'beca'), (4.9, 163, 'beca')], '2': [(5.0, 244, 'beca'), (4.9, 492, 'beca'), (4.9, 208, 'beca'), (4.9, 8, 'beca')], '3': [(4.9, 472, 'beca'), (4.9, 61, 'beca'), (4.7, 110, 'beca')]}
# id becados por estrato {'1': [377, 364, 163], '2': [244, 492, 208, 8], '3': [472, 61, 110]}

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
#código

#agrupación e indexacion
indice = 0
region_genero_promedio =[]
for i in range(len(diccionarios_datos['promedio'])):
    indice = indice +1
    region_genero_promedio.append((diccionarios_datos["region"][i], diccionarios_datos["genero"][i], float(diccionarios_datos['promedio'][i]), indice))

combinaciones = []  
for i in set([i[0] for i in region_genero_promedio]):
    for j in set([i[1] for i in region_genero_promedio]):
        combinaciones.append((i,j))

diccionario_region_genero = {}        
for i in combinaciones:
    datos = []
    for j in range(len(region_genero_promedio)):
        if i[0] == region_genero_promedio[j][0] and i[1] == region_genero_promedio[j][1]:
             datos.append((region_genero_promedio[j][2], region_genero_promedio[j][3]))
        diccionario_region_genero[i] = sorted(datos, reverse = True)
    


repartir_becas = []
for i in diccionario_region_genero:
    repartir_becas.append((i ,(len(diccionario_region_genero[i]))))

##40 becas en 20 grupos: 2 becas por grupo 


dar = 0
becas_por_dar = []
for i in repartir_becas:
    if i[1] > 1:
        dar = 2 
    else:
        dar = 0
    becas_por_dar.append((i[0], i[1], dar)) 





vector_completo=[]
for i in set([i[0][0] for i in becas_por_dar]):
    vector_2 = []
    for j in becas_por_dar:
        if j[0][0] == i:
            vector_2.append((j[1]))
            vector_2 = sorted(vector_2, reverse =True)
    vector_completo +=  vector_2[:1]


diccionario_maximos_final={}

for i in vector_completo:
    for j in diccionario_region_genero:
        if len(diccionario_region_genero[j]) == i:
            diccionario_maximos_final[j] =i


    

#becas tambien para generos nicos 
becados_dicc = {} #(region, genero ): promedio, id
conteo2=0
for i in diccionario_region_genero:
    becados_1=[]
    for j in range(len(diccionario_region_genero[i])):
        if j +1 <= 2:
            becados_1.append(diccionario_region_genero[i][j])
    becados_dicc[i] = becados_1

#sumas
suma_comp = []    
for i in set([i[0] for i in becados_dicc]):
    x=0
    for j in becados_dicc:
        if i == j[0]:
            x += len(becados_dicc[j])
    suma_comp.append((i,x))

#40/5 regiones     
becas_posibles = int(40/len(suma_comp))
particiones = []
for i in suma_comp:
    
    c = 0
    for j in diccionario_maximos_final:
        if i[0] == j[0]:
            c += 1
    particiones.append((i,c))

#reparticion de becas de acuerdo a la particion de las poblaciones cuando el maximo de la poblacion es igual en varias 
    
for i in particiones:
    entregar = becas_posibles - i[0][1]
    for j in diccionario_maximos_final:
        if i[0][0] == j[0]:
            if i[1] > 1:
                dar = int(entregar/i[1])
                entregar += dar 
                
            else:
                dar = entregar
                
            becados_dicc[j]+=(diccionario_region_genero[j][2:dar+2])


conteo_final = 0
for i in becados_dicc:
    for j in becados_dicc[i]:
        conteo_final +=1 
conteo_final,becados_dicc
# Out:
# (40,
#  {('Amazonia', 'femenino'): [(4.6, 479), (2.9, 221)],
#   ('Amazonia', 'otro'): [(3.1, 196), (3.0, 457)],
#   ('Amazonia', 'masculino'): [(4.5, 50), (3.3, 489)],
#   ('Amazonia', 'no binario'): [(1.5, 376), (0.5, 242)],
#   ('Caribe', 'femenino'): [(5.0, 244), (4.9, 61)],
#   ('Caribe', 'otro'): [(3.6, 137), (0.1, 165)],
#   ('Caribe', 'masculino'): [(4.9, 492), (4.6, 160)],
#   ('Caribe', 'no binario'): [(4.3, 23), (4.0, 97)],
#   ('Andina', 'femenino'): [(4.9, 208), (4.9, 8)],
#   ('Andina', 'otro'): [(2.4, 374)],
#   ('Andina', 'masculino'): [(4.9, 163), (4.8, 395), (4.5, 453)],
#   ('Andina', 'no binario'): [(4.8, 284), (4.8, 260)],
#   ('Orinoquia', 'femenino'): [(3.9, 114), (3.4, 100), (3.0, 229)],
#   ('Orinoquia', 'otro'): [(2.1, 5)],
#   ('Orinoquia', 'masculino'): [(4.2, 423), (4.0, 139), (3.8, 195), (3.2, 215)],
#   ('Orinoquia', 'no binario'): [],
#   ('Pacifica', 'femenino'): [(4.9, 364), (4.7, 110), (4.4, 356), (4.3, 288)],
#   ('Pacifica', 'otro'): [],
# ...

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
# código

#grupo 1
diccionario_promedios_grupo_1 ={}
for i in becados_total:
    promedios = []
    for j in becados_total[i]:
        promedios.append(j[0])
    diccionario_promedios_grupo_1[i] = promedios
diccionario_promedios_grupo_1  


#grupo 2

diccionario_promedios_grupo_2 ={}
for i in becados_dicc:
    promedios = []
    for j in becados_dicc[i]:
        promedios.append(j[0])
    diccionario_promedios_grupo_2[i] = promedios
diccionario_promedios_grupo_2   

#union 
diccionario_promedios_grupo_1.update(diccionario_promedios_grupo_2)

def multiples_boxplot_nuevos_req (dicc):
    c = 0
    for i in dicc:
        if dicc[i] != []:
            c += 1
            
            if c == len(dicc) + 1:
                break
            else:
                ax =plt.subplot(4,6,c)
                ax.boxplot(dicc[i])
                plt.ylabel(i, fontsize=10)
                
                if i in ("1","2","3"):
                    tit = "grupo_1"
                else:
                    tit = "grupo_2"
                plt.title(tit)
                plt.tight_layout()
                plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=2, 
                    top=2.5, 
                    wspace=2, 
                    hspace=2)
                
                
multiples_boxplot_nuevos_req(diccionario_promedios_grupo_1)    
#tabla
for i in diccionario_promedios_grupo_1:
    if diccionario_promedios_grupo_1[i] != []:
        promedio = round(sum(diccionario_promedios_grupo_1[i])/len(diccionario_promedios_grupo_1[i]),2)
        median = round(mediana(diccionario_promedios_grupo_1[i]),2)
        desviacion = round(desv(diccionario_promedios_grupo_1[i]),2)
        numero_becas = len(diccionario_promedios_grupo_1[i])
        if i in ("1","2","3"):
            g = "grupo_1"
        else:
            g = "grupo_2"
        print(g, i, "promedio:", promedio, "mediana:", median, "dstd:", desviacion, "nro becas:",numero_becas)
# Out:
# grupo_1 1 promedio: 4.93 mediana: 4.9 dstd: 0.05 nro becas: 3
# grupo_1 2 promedio: 4.93 mediana: 4.9 dstd: 0.04 nro becas: 4
# grupo_1 3 promedio: 4.83 mediana: 4.9 dstd: 0.09 nro becas: 3
# grupo_2 ('Amazonia', 'femenino') promedio: 3.75 mediana: 3.75 dstd: 0.85 nro becas: 2
# grupo_2 ('Amazonia', 'otro') promedio: 3.05 mediana: 3.05 dstd: 0.05 nro becas: 2
# grupo_2 ('Amazonia', 'masculino') promedio: 3.9 mediana: 3.9 dstd: 0.6 nro becas: 2
# grupo_2 ('Amazonia', 'no binario') promedio: 1.0 mediana: 1.0 dstd: 0.5 nro becas: 2
# grupo_2 ('Caribe', 'femenino') promedio: 4.95 mediana: 4.95 dstd: 0.05 nro becas: 2
# grupo_2 ('Caribe', 'otro') promedio: 1.85 mediana: 1.85 dstd: 1.75 nro becas: 2
# grupo_2 ('Caribe', 'masculino') promedio: 4.75 mediana: 4.75 dstd: 0.15 nro becas: 2
# grupo_2 ('Caribe', 'no binario') promedio: 4.15 mediana: 4.15 dstd: 0.15 nro becas: 2
# grupo_2 ('Andina', 'femenino') promedio: 4.9 mediana: 4.9 dstd: 0.0 nro becas: 2
# ...

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
# código

edad=set([int(i) for i in diccionarios_datos["edad"]])
#edades
r_inf =  0
r_superior = 0
while True:
    r_inf= int(input("Rango inferior:ingrese edad superior o igual" +" "+ str( min(edad)) + " " +"y menor igual a" +" " +str( max(edad)))) 
    r_superior= int(input("Rango superior:ingrese edad superior o igual" +" "+ str(min(edad))  +" "+ "y menor igual a" + str(max(edad))))
    if r_inf >= min(edad) and r_superior <= max(edad):
        break
    else:
        print("ingrese valores validos y que se encuentren en el rango")
    

#criterios
criterio = ""
criterio_final = ""

while criterio not in  ("1", "2", "3", "4"):
    criterio = input("ingrese el numero correspondiente alguno de estos criterios:  1: genero, 2: region, 3: estrato: ")
    if criterio == "1":
         criterio_final = "genero"
    elif criterio == "2":
        criterio_final = "region"
    elif criterio == "3":
        criterio_final = "estrato"
    else:
        print("escoja un criterio valido")
    

#grupos
grupos = list(set([i for i in diccionarios_datos[criterio_final]]))


#proporciones
i = 0
diccicionario_proprociones = {}
while True:
    c = float(input("ingrese la proporcion para este grupo (de 0 a 1) :"  + grupos[i] + " " + "lleva:"))
    diccicionario_proprociones[grupos[i]] = c 
    if i+1 == len(grupos):
        break
    i +=1 

#modelo
becas_met = []   
ind= 0
for j in range(len(diccionarios_datos[criterio_final])):
    ind += 1
    if int(diccionarios_datos["edad"][j]) >= r_inf  and int(diccionarios_datos["edad"][j]) <= r_superior:
        becas_met.append((float(diccionarios_datos["promedio"][j]), diccionarios_datos[criterio_final][j], int(diccionarios_datos["edad"][j]), ind))
        
diccionario_met = {}#estrato, promedio, id
for i in sorted(set([i[1] for i in becas_met])):  
    valores = []
    for j in becas_met:
        if i == j[1]:
            valores.append((j[0], j[2], j[3]))
            c= valores 
        diccionario_met[i] =sorted(valores, reverse =True) ##validar datos
diccionario_met

#becas a dar 
total_becas = 10

becas_dadas_met = {}
for i in diccionario_met:
    p = diccicionario_proprociones[i]
    becas_dadas_met[i]= (diccionario_met[i][:int(total_becas*p)])

nro_becados_met = 0    
for i in becas_dadas_met:
    for j in becas_dadas_met[i]:
        nro_becados_met+=1

sacar = []
for i in becas_dadas_met:
    for j in range(len(becas_dadas_met[i])):
        sacar.append(becas_dadas_met[i][j][2])

    for k in sacar:
        for j in range(len(diccionario_met[i])):
            if diccionario_met[i][j][2] == k:
            
                del diccionario_met[i][j]
                break
#hasta completar el numero de becas a dar             
if nro_becados_met < total_becas:
    n=0
    while n +1<=  (total_becas - nro_becados_met) :
        for i in diccionario_met:  
            p = diccicionario_proprociones[i]
            becas_dadas_met[i] += diccionario_met[i][:1]
            n +=1
            if n  == (total_becas - nro_becados_met):
                break
            
            
            for k in sacar:
                for j in range(len(diccionario_met[i])):
                    if diccionario_met[i][j][2] == k:
                        del diccionario_met[i][j]
                        break

#visualizacion de resultadso
diccionario_visualizacion={}
for i in becas_dadas_met:
    contenido = []
    for j in becas_dadas_met[i]:
        contenido.append(j[0])
    diccionario_visualizacion[i] =contenido
diccionario_visualizacion


for i in diccionario_visualizacion:
    if diccionario_visualizacion[i]!=[]:
        plt.boxplot(diccionario_visualizacion[i])
        plt.title(i)
        plt.xlabel(i)
        plt.ylabel("promedio")
        plt.show()

becas_dadas_met
# Out:
# Rango inferior:ingrese edad superior o igual 18 y menor igual a 8018
# Rango superior:ingrese edad superior o igual 18 y menor igual a8032
# ingrese el numero correspondiente alguno de estos criterios:  1: genero, 2: region, 3: estrato: 1
# ingrese la proporcion para este grupo (de 0 a 1) :femenino lleva:0.25
# ingrese la proporcion para este grupo (de 0 a 1) :otro lleva:0.25
# ingrese la proporcion para este grupo (de 0 a 1) :masculino lleva:0.25
# ingrese la proporcion para este grupo (de 0 a 1) :no binario lleva:0.25
# {'femenino': [(4.9, 32, 364), (4.9, 21, 208), (4.6, 27, 479)],
#  'masculino': [(4.9, 21, 472), (4.5, 20, 50), (4.4, 26, 162)],
#  'no binario': [(4.8, 28, 284), (3.3, 30, 67), (2.2, 25, 314)],
#  'otro': [(2.1, 26, 5)]}

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

respuesta = 'Se propone darle becas de manera escalonada por estrato a las personas con mejores promedios sin importar otras caracteristicas. De tal manera que, se dara el 35%, 30%, 25%, 5% y 5%  de las becas disponibles a los estratos 1,2,3,4,5, respectivamente, para personas mayores de 18 años y menores de 28. La virtud es que permite un mejor inclusión en terminos socioeconomicos generando equidad y no sesgandose por otros atributos que presentan mayor volatilidad al momento de evaluarse en terminos de promedios. Es observable que los promedios altos presentan menos volatilidad cuando se miran por estratos'

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
# código
edad=set([int(i) for i in diccionarios_datos["edad"]])

r_inf =  0
r_superior = 0
while True:
    r_inf= int(input("Rango inferior:ingrese edad superior o igual" +" "+ str( min(edad)) + " " +"y menor igual a" +" " +str( max(edad)))) 
    r_superior= int(input("Rango superior:ingrese edad superior o igual" +" "+ str(min(edad))  +" "+ "y menor igual a" + str(max(edad))))
    if r_inf >= min(edad) and r_superior <= max(edad):
        break
    else:
        print("ingrese valores validos y que se encuentren en el rango")
    


criterio = ""
criterio_final = ""

while criterio not in  ("1", "2", "3", "4"):
    criterio = input("ingrese el numero correspondiente alguno de estos criterios:  1: genero, 2: region, 3: estrato: ")
    if criterio == "1":
         criterio_final = "genero"
    elif criterio == "2":
        criterio_final = "region"
    elif criterio == "3":
        criterio_final = "estrato"
    else:
        print("escoja un criterio valido")
    


grupos = list(set([i for i in diccionarios_datos[criterio_final]]))



i = 0
diccicionario_proprociones = {}
while True:
    c = float(input("ingrese la proporcion para este grupo (de 0 a 1) :"  + grupos[i] + " " + "lleva:"))
    diccicionario_proprociones[grupos[i]] = c 
    if i+1 == len(grupos):
        break
    i +=1 

    
becas_met = []   
ind= 0
for j in range(len(diccionarios_datos[criterio_final])):
    ind += 1
    if int(diccionarios_datos["edad"][j]) >= r_inf  and int(diccionarios_datos["edad"][j]) <= r_superior:
        becas_met.append((float(diccionarios_datos["promedio"][j]), diccionarios_datos[criterio_final][j], int(diccionarios_datos["edad"][j]), ind))
        
diccionario_met = {}#estrato, promedio, id
for i in sorted(set([i[1] for i in becas_met])):  
    valores = []
    for j in becas_met:
        if i == j[1]:
            valores.append((j[0], j[2], j[3]))
            c= valores 
        diccionario_met[i] =sorted(valores, reverse =True) ##validar datos
diccionario_met


total_becas = 10

becas_dadas_met = {}
for i in diccionario_met:
    p = diccicionario_proprociones[i]
    becas_dadas_met[i]= (diccionario_met[i][:int(total_becas*p)])

nro_becados_met = 0    
for i in becas_dadas_met:
    for j in becas_dadas_met[i]:
        nro_becados_met+=1

sacar = []
for i in becas_dadas_met:
    for j in range(len(becas_dadas_met[i])):
        sacar.append(becas_dadas_met[i][j][2])

    for k in sacar:
        for j in range(len(diccionario_met[i])):
            if diccionario_met[i][j][2] == k:
            
                del diccionario_met[i][j]
                break
            
if nro_becados_met < total_becas:
    n=0
    while n +1<=  (total_becas - nro_becados_met) :
        for i in diccionario_met:  
            p = diccicionario_proprociones[i]
            becas_dadas_met[i] += diccionario_met[i][:1]
            n +=1
            if n  == (total_becas - nro_becados_met):
                break
            
            
            for k in sacar:
                for j in range(len(diccionario_met[i])):
                    if diccionario_met[i][j][2] == k:
                        del diccionario_met[i][j]
                        break
print(becas_dadas_met)

diccionario_visualizacion={}
for i in becas_dadas_met:
    contenido = []
    for j in becas_dadas_met[i]:
        contenido.append(j[0])
    diccionario_visualizacion[i] =contenido
diccionario_visualizacion


for i in diccionario_visualizacion:
    if diccionario_visualizacion[i]!=[]:
        plt.boxplot(diccionario_visualizacion[i])
        plt.title(i)
        plt.xlabel(i)
        plt.ylabel("promedio")
        plt.show()

becas_dadas_met
conclusion = 'Al asignar becas por estrato, de manera escalonada a jovenes, se presentan restulados más homogeneos en terminos de promedio altos, y que permite continuar con el espiritu de la Universidad y con el porposito de las becas. Las evaluacion por región y genero presenta mayor volatilidade en terminos de promedio'
# Out:
# Rango inferior:ingrese edad superior o igual 18 y menor igual a 8018
# Rango superior:ingrese edad superior o igual 18 y menor igual a8028
# ingrese el numero correspondiente alguno de estos criterios:  1: genero, 2: region, 3: estrato: 3
# ingrese la proporcion para este grupo (de 0 a 1) :4 lleva:0.05
# ingrese la proporcion para este grupo (de 0 a 1) :2 lleva:0.3
# ingrese la proporcion para este grupo (de 0 a 1) :3 lleva:0.25
# ingrese la proporcion para este grupo (de 0 a 1) :1 lleva:0.35
# ingrese la proporcion para este grupo (de 0 a 1) :5 lleva:0.05
# {'1': [(4.8, 28, 284), (4.3, 20, 288), (4.0, 25, 251), (3.7, 24, 467)], '2': [(4.9, 21, 208), (4.6, 27, 479), (4.0, 23, 338), (3.9, 26, 34)], '3': [(4.9, 21, 472), (4.5, 20, 50)], '4': [], '5': []}

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
